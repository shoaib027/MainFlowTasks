# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('sample.csv')

# %%
data
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data.head()
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
data.sort_index(axis = 1, ascending = False)
# Out:
#      Y-Kappa  WhiteFlow-4   WeakWashF   WeakLiquorF   Upper-HeatT-3   UCZAA  \
# 0      23.10       599.253     257.325      1127.197         303.099  1.443
# 1      27.60       537.201     241.182       665.975         304.879  1.549
# 2      23.19       549.611     237.272       677.534         303.383  1.600
# 3      23.60       623.362     239.478       767.853         302.254  1.604
# 4      22.90       638.672     215.372       888.448         300.954    NaN
# ..       ...           ...         ...           ...             ...    ...
# 319    23.75       513.956     381.643      1027.201         304.006  1.523
# 320    19.80       570.058      25.494       906.962         304.616  1.451
# 321    23.01       549.306       0.638       887.125         304.686  1.457
# 322    24.32       504.852       0.000       804.423         304.363  1.523
# 323    25.75       497.375       1.276       828.328         304.093  1.474
#
# ...

# %%
#Takes transpose of the DataFrame
data.T
# Out:
#                       0         1         2         3         4         5    \
# Observation      31-00:00  31-01:00  31-02:00  31-03:00  31-04:00   1-08:00
# Y-Kappa              23.1      27.6     23.19      23.6      22.9     14.23
# ChipRate            16.52     16.81    16.709    16.478    15.618     15.35
# BF-CMratio        121.717    79.022    79.562    81.011    93.244    85.518
# BlowFlow         1177.607   1328.36  1329.407  1334.877  1334.168  1171.604
# ChipLevel4        169.805   341.327   239.161   213.527   243.131   198.538
# T-upperExt-2      358.282    351.05   350.022   350.938    351.64   344.014
# T-lowerExt-2      329.545   329.067    329.26   331.142   332.709   325.195
# UCZAA               1.443     1.549       1.6     1.604       NaN     1.436
# WhiteFlow-4       599.253   537.201   549.611   623.362   638.672   628.245
# AAWhiteSt-4           NaN     6.076       NaN     6.054      6.11      6.02
# ...

# %%
#Filtering the Data
data[data['Y-Kappa']>25]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 12     31-11:00    26.62    15.467      84.447  1334.255      386.971
# 13     31-12:00    27.20    16.083      82.839  1332.331      366.855
# 15     31-14:00    25.40    16.425      72.924  1197.775      118.821
# 40      1-15:00    27.10    13.558      83.117  1175.417      289.256
# 64      2-15:00    25.40    16.958      74.405  1230.776      295.522
# 80      3-07:00    26.50    16.300      75.411  1229.199      358.256
# 121     5-00:00    25.56    14.900      84.953  1289.167      373.726
# 123     5-02:00    25.30    15.225      82.030  1280.837      312.879
# 151     6-06:00    26.02    15.800      79.293  1291.149      271.419
# 167     6-22:00    25.10    15.075      80.024  1281.051      343.214
# 168     6-23:00    25.52    16.008      77.070  1285.782      338.656
# ...

# %%
data['Y-Kappa']
# Out:
# 0      23.10
# 1      27.60
# 2      23.19
# 3      23.60
# 4      22.90
#        ...
# 319    23.75
# 320    19.80
# 321    23.01
# 322    24.32
# 323    25.75
# Name: Y-Kappa, Length: 324, dtype: float64

# %%
#Summarizing the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      324 non-null    object
#  1   Y-Kappa          324 non-null    float64
#  2   ChipRate         319 non-null    float64
#  3   BF-CMratio       307 non-null    float64
#  4   BlowFlow         308 non-null    float64
#  5   ChipLevel4       323 non-null    float64
#  6   T-upperExt-2     322 non-null    float64
#  7   T-lowerExt-2     322 non-null    float64
#  8   UCZAA            299 non-null    float64
#  9   WhiteFlow-4      323 non-null    float64
#  10  AAWhiteSt-4      173 non-null    float64
#  11  AA-Wood-4        323 non-null    float64
#  12  ChipMoisture-4   323 non-null    float64
#  13  SteamFlow-4      323 non-null    float64
#  14  Lower-HeatT-3    322 non-null    float64
#  15  Upper-HeatT-3    322 non-null    float64
# ...

# %%
data.columns
# Out:
# Index(['Observation', 'Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow',
#        'ChipLevel4 ', 'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA',
#        'WhiteFlow-4 ', 'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ',
#        'SteamFlow-4 ', 'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ',
#        'WeakLiquorF ', 'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ',
#        'T-Top-Chips-4 ', 'SulphidityL-4 '],
#       dtype='object')

# %%
#Count missing values per each column
data.isna().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %%
#Checking value counts for a specific value
data['Y-Kappa'].value_counts()
# Out:
# Y-Kappa
# 17.80    5
# 21.40    5
# 22.30    4
# 16.20    4
# 23.50    4
#         ..
# 18.40    1
# 26.02    1
# 19.78    1
# 19.22    1
# 20.89    1
# Name: count, Length: 216, dtype: int64

# %%
data.nunique()
# Out:
# Observation        301
# Y-Kappa            216
# ChipRate           243
# BF-CMratio         286
# BlowFlow           286
# ChipLevel4         291
# T-upperExt-2       286
# T-lowerExt-2       282
# UCZAA              172
# WhiteFlow-4        294
# AAWhiteSt-4         99
# AA-Wood-4          208
# ChipMoisture-4     286
# SteamFlow-4        292
# Lower-HeatT-3      292
# Upper-HeatT-3      298
# ChipMass-4         291
# WeakLiquorF        295
# BlackFlow-2        296
# WeakWashF          275
# SteamHeatF-3       298
# T-Top-Chips-4      258
# SulphidityL-4      129
# dtype: int64

# %%
data.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...

# %%
#Count not null values of each column
data.count()
# Out:
# Observation        324
# Y-Kappa            324
# ChipRate           319
# BF-CMratio         307
# BlowFlow           308
# ChipLevel4         323
# T-upperExt-2       322
# T-lowerExt-2       322
# UCZAA              299
# WhiteFlow-4        323
# AAWhiteSt-4        173
# AA-Wood-4          323
# ChipMoisture-4     323
# SteamFlow-4        323
# Lower-HeatT-3      322
# Upper-HeatT-3      322
# ChipMass-4         323
# WeakLiquorF        323
# BlackFlow-2        322
# WeakWashF          323
# SteamHeatF-3       322
# T-Top-Chips-4      323
# SulphidityL-4      173
# dtype: int64

# %%
#Filling the missing values with the interpolated data
data_interpolated = data.interpolate()
# Out:
# C:\Users\MD SHOAIB HASAN\AppData\Local\Temp\ipykernel_6800\177403374.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data_interpolated = data.interpolate()

# %%
data_interpolated
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data_interpolated.isna().sum()
# Out:
# Observation        0
# Y-Kappa            0
# ChipRate           0
# BF-CMratio         0
# BlowFlow           0
# ChipLevel4         0
# T-upperExt-2       0
# T-lowerExt-2       0
# UCZAA              0
# WhiteFlow-4        0
# AAWhiteSt-4        1
# AA-Wood-4          0
# ChipMoisture-4     0
# SteamFlow-4        0
# Lower-HeatT-3      0
# Upper-HeatT-3      0
# ChipMass-4         0
# WeakLiquorF        0
# BlackFlow-2        0
# WeakWashF          0
# SteamHeatF-3       0
# T-Top-Chips-4      0
# SulphidityL-4      1
# dtype: int64

# %%
#Saving the interpolated values to the original csv file
data_interpolated.to_csv('sample.csv', index=False)

# %%
#Now reading the csv again to check if the csv is updated
data = pd.read_csv('sample.csv')

# %%
data.count()
# Out:
# Observation        324
# Y-Kappa            324
# ChipRate           324
# BF-CMratio         324
# BlowFlow           324
# ChipLevel4         324
# T-upperExt-2       324
# T-lowerExt-2       324
# UCZAA              324
# WhiteFlow-4        324
# AAWhiteSt-4        323
# AA-Wood-4          324
# ChipMoisture-4     324
# SteamFlow-4        324
# Lower-HeatT-3      324
# Upper-HeatT-3      324
# ChipMass-4         324
# WeakLiquorF        324
# BlackFlow-2        324
# WeakWashF          324
# SteamHeatF-3       324
# T-Top-Chips-4      324
# SulphidityL-4      323
# dtype: int64

# %%
data.isna().sum()
# Out:
# Observation        0
# Y-Kappa            0
# ChipRate           0
# BF-CMratio         0
# BlowFlow           0
# ChipLevel4         0
# T-upperExt-2       0
# T-lowerExt-2       0
# UCZAA              0
# WhiteFlow-4        0
# AAWhiteSt-4        1
# AA-Wood-4          0
# ChipMoisture-4     0
# SteamFlow-4        0
# Lower-HeatT-3      0
# Upper-HeatT-3      0
# ChipMass-4         0
# WeakLiquorF        0
# BlackFlow-2        0
# WeakWashF          0
# SteamHeatF-3       0
# T-Top-Chips-4      0
# SulphidityL-4      1
# dtype: int64
